# %% [markdown]
# # Streaming
#
# ## Review
#
# In module 2, covered a few ways to customize graph state and memory.
#
# We built up to a Chatbot with external memory that can sustain long-running conversations.
#
# ## Goals
#
# This module will dive into `human-in-the-loop`, which builds on memory and allows users to interact directly with graphs in various ways.
#
# To set the stage for `human-in-the-loop`, we'll first dive into streaming, which provides several ways to visualize graph output (e.g., node state or chat model tokens) over the course of execution.

# %% [markdown]
# ## Streaming
#
# LangGraph is built with [first class support for streaming](https://docs.langchain.com/oss/python/langgraph/streaming).
#
# Let's set up our Chatbot from Module 2, and show various way to stream outputs from the graph during execution.

# %%
from IPython.display import Image, display
from typing import Literal

from langchain.chat_models import init_chat_model
from langchain_core.messages import SystemMessage, HumanMessage, RemoveMessage
from langchain_core.runnables import RunnableConfig

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START, END
from langgraph.graph import MessagesState

# LLM
model = init_chat_model(
    model="openai/gpt-oss-120b", 
    model_provider="groq"
)

# State 
class State(MessagesState):
    summary: str

# Define the logic to call the model
def call_model(state: State, config: RunnableConfig):
    
    # Get summary if it exists
    summary = state.get("summary", "")

    # If there is summary, then we add it
    if summary:
        
        # Add summary to system message
        system_message = f"Summary of conversation earlier: {summary}"

        # Append summary to any newer messages
        messages = [SystemMessage(content=system_message)] + state["messages"]
    
    else:
        messages = state["messages"]
    
    response = model.invoke(messages, config)
    return {"messages": response}

def summarize_conversation(state: State):
    
    # First, we get any existing summary
    summary = state.get("summary", "")

    # Create our summarization prompt 
    if summary:
        
        # A summary already exists
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )
        
    else:
        summary_message = "Create a summary of the conversation above:"

    # Add prompt to our history
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    response = model.invoke(messages)
    
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# Determine whether to end or summarize the conversation
def should_continue(state: State)-> Literal ["summarize_conversation",END]:
    
    """Return the next node to execute."""
    
    messages = state["messages"]
    
    # If there are more than six messages, then we summarize the conversation
    if len(messages) > 6:
        return "summarize_conversation"
    
    # Otherwise we can just end
    return END

# Define a new graph
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node(summarize_conversation)

# Set the entrypoint as conversation
workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

# Compile
memory = MemorySaver()
graph = workflow.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Streaming full state
#
# Now, let's talk about ways to [stream our graph state](https://docs.langchain.com/oss/python/langgraph/streaming#supported-stream-modes).
#
# `.stream` and `.astream` are sync and async methods for streaming back results.
#
# LangGraph supports a few [different streaming modes](https://docs.langchain.com/oss/python/langgraph/streaming#stream-graph-state) for graph state.
#
# * `values`: This streams the full state of the graph after each node is called.
# * `updates`: This streams updates to the state of the graph after each node is called.
#
# ![values_vs_updates.png](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbaf892d24625a201744e5_streaming1.png)
#
# Let's look at `stream_mode="updates"`.
#
# Because we stream with `updates`, we only see updates to the state after node in the graph is run.
#
# Each `chunk` is a dict with `node_name` as the key and the updated state as the value.

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}

# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Lance")]}, config, stream_mode="updates"):
    print(chunk)
# Out:
# {'conversation': {'messages': AIMessage(content="Hey Lance! 👋 Nice to meet you. How's your day going?", additional_kwargs={'reasoning_content': 'The user says "hi! I\'m Lance". We should respond friendly. No policy issues.'}, response_metadata={'token_usage': {'completion_tokens': 44, 'prompt_tokens': 75, 'total_tokens': 119, 'completion_time': 0.095207378, 'completion_tokens_details': {'reasoning_tokens': 19}, 'prompt_time': 0.003356665, 'prompt_tokens_details': None, 'queue_time': 0.15047546, 'total_time': 0.098564043}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_9d1f936695', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a07cff-88f5-7972-b5d2-dedc5a3660b0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 75, 'output_tokens': 44, 'total_tokens': 119, 'output_token_details': {'reasoning': 19}})}}

# %% [markdown]
# Let's now just print the state update.

# %%
# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Lance")]}, config, stream_mode="updates"):
    chunk['conversation']["messages"].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Hey again, Lance! 😊 What’s on your mind today?

# %% [markdown]
# Now, we can see `stream_mode="values"`.
#
# This is the `full state` of the graph after the `conversation` node is called.

# %%
# Start conversation, again
config = {"configurable": {"thread_id": "2"}}

# Start conversation
input_message = HumanMessage(content="hi! I'm Lance")
for event in graph.stream({"messages": [input_message]}, config, stream_mode="values"):
    for m in event['messages']:
        m.pretty_print()
    print("---"*25)
# Out:
# ================================ Human Message =================================
#
# hi! I'm Lance
# ---------------------------------------------------------------------------
# ================================ Human Message =================================
#
# hi! I'm Lance
# ================================== Ai Message ==================================
#
# Hey Lance! 👋 Great to meet you. How can I help you today?
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Streaming tokens
#
# We often want to stream more than graph state.
#
# In particular, with chat model calls it is common to stream the tokens as they are generated.
#
# We can do this [using the `.astream_events` method](https://docs.langchain.com/oss/python/langchain/models#advanced-streaming-topics:streaming-events), which streams back events as they happen inside nodes!
#
# Each event is a dict with a few keys:
#
# * `event`: This is the type of event that is being emitted.
# * `name`: This is the name of event.
# * `data`: This is the data associated with the event.
# * `metadata`: Contains`langgraph_node`, the node emitting the event.
#
# Let's have a look.

# %%
config = {"configurable": {"thread_id": "3"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    print(f"Node: {event['metadata'].get('langgraph_node','')}. Type: {event['event']}. Name: {event['name']}")
# Out:
# Node: . Type: on_chain_start. Name: LangGraph
# Node: conversation. Type: on_chain_start. Name: conversation
# Node: conversation. Type: on_chat_model_start. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# ...
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_end. Name: ChatGroq
# Node: conversation. Type: on_chain_start. Name: should_continue
# Node: conversation. Type: on_chain_end. Name: should_continue
# Node: conversation. Type: on_chain_stream. Name: conversation
# Node: conversation. Type: on_chain_end. Name: conversation
# Node: . Type: on_chain_stream. Name: LangGraph
# Node: . Type: on_chain_end. Name: LangGraph

# %% [markdown]
# The central point is that tokens from chat models within your graph have the `on_chat_model_stream` type.
#
# We can use `event['metadata']['langgraph_node']` to select the node to stream from.
#
# And we can use `event['data']` to get the actual data for each event, which in this case is an `AIMessageChunk`.

# %%
node_to_stream = 'conversation'
config = {"configurable": {"thread_id": "4"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        print(event["data"])
# Out:
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': 'The'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' user'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' wants'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' information'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' about'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' the'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' '}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': '49'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': 'ers'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' NFL'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' team'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': '.'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' Provide'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' overview'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ':'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' history'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ','}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' championships'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ','}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' notable'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' players'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ','}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' recent'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' performance'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ','}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' stadium'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ','}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' culture'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ','}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' etc'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': '.'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' Ensure'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' no'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' dis'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': 'allowed'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' content'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': '.'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': " It's"}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' fine'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': '.'}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='San', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Francisco', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\u202f', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' –', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Quick', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Overview', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**\n\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Category', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Details', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='----------', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='---------', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Founded', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='194', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='6', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='joined', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' NFL', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='194', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Location', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' San', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Francisco', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bay', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Area', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' California', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Home', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Stadium', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Le', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='vi', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='’s', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Stadium', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Santa', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Clara', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' CA', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' –', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' opened', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='201', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' capacity', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ~', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='68', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='500', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Team', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Colors', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Scarlet', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' red', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' gold', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' white', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Conference', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='/', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Division', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' NFC', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' West', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='National', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Football', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Conference', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Owner', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Denise', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' De', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Bart', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='olo', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' York', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='principal', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' &', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' John', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' York', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='co', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='‑', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='owner', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='General', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Manager', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='John', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Lynch', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='since', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='202', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Head', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Coach', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Kyle', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Shan', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ahan', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='since', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='201', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='7', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='All', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='‑', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Time', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Record', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='as', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# ...
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' secondary', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' while', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' maintaining', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' strong', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' pass', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='‑', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='rush', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' core', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='B', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='osa', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Iss', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='a', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=').', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='  \n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='3', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Off', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ensive', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Evolution', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' –', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Expect', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' more', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='R', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='PO', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='run', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='‑', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='pass', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' option', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' concepts', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' leverage', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Mc', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='C', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='aff', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='rey', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='’s', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' dual', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' threat', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' K', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ittle', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='’s', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' versatility', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='  \n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='St', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='adium', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' &', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Revenue', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' –', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Levi', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='’s', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Stadium', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'length', 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_c868cf1eaa', 'service_tier': 'on_demand'}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 80, 'output_tokens': 3072, 'total_tokens': 3152, 'output_token_details': {'reasoning': 41}}, tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--01a07d00-44f7-7302-b47d-7269de7b92b2', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[], chunk_position='last')}

# %% [markdown]
# As you see above, just use the `chunk` key to get the `AIMessageChunk`.

# %%
config = {"configurable": {"thread_id": "5"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        data = event["data"]
        print(data["chunk"].content, end="|")
# Out:
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||**|San| |Franc|isco| |49|ers| –| Quick| Overview|**
#
# ||| Category| || Details| |
# |||----------|||---------||
# ||| **|Founded|**| || |194|6| (|as| a| charter| member| of| the| All|‑|America| Football| Conference|);| joined| the| NFL| in| |195|0| |
# ||| **|Location|**| || San| |Franc|isco| Bay| Area|,| California| |
# ||| **|Home| Stadium|**| || **|Le|vi|’s| Stadium|**| in| Santa| Clara| (|opened| |201|4|)| –| capacity| ~|68|,|500| |
# ||| **|Team| Colors|**| || Scarlet| red|,| gold|,| and| white| |
# ||| **|Nickname|**| || “|The| N|iners|”| |
# ||| **|Owner|**| || The| De|Bart|olo| family| (|John| |J|.| |De|Bart|olo| |III|)| |
# ||| **|Head| Coach| (|202|4|)**| || **|Kyle| Shan|ahan|**| (|since| |201|7|)| |
# ||| **|General| Manager|**| || **|John| |L|.| |Har|b|augh|**| (|since| |201|7|)| |
# ||| **|Conference|/|Division|**| || NFC| West| |
# ||| **|All|‑|Time| Record| (|regular| season|)**| || ~|730|‑|560|‑|16| (|as| of| the| end| of| the| |202|3| season|)| |
#
# |---
#
# |##| Historical| Highlights|
#
# ||| Era| || Key| Points| |
# |||-----|||------------||
# ||| **|Early| Years| (|194|6|‑|197|8|)**| || •| Won| the| |195|2| NFL| Championship| (|first| league| title|).| <|br|>|•| Str|ugg|led| through| the| |196|0|s| and| early| ’|70|s|,| often| finishing| near| the| bottom| of| the| league|.| |
# ||| **|The| Bill| Walsh| Era| (|197|9|‑|198|8|)**| || •| H|ired| **|Bill| Walsh|**| as| head| coach| in| |197|9|.| <|br|>|•| Introdu|ced| the| “|West| Coast| Off|ense|,”| a| short|‑|passing|,| timing|‑|based| attack| that| resh|aped| modern| NFL| offenses|.| <|br|>|•| Won| **|three| Super| Bow|ls|**| (|X|VI| |199|2|,| XIX| |199|5|,| XX|III| |198|9|).| |
# ||| **|Joe| |Mont|ana| &| The| “|Gold| Rush|”| (|198|0|s|‑|early| ’|90|s|)**| || •| Quarter|back| **|Joe| |Mont|ana|**| (|draft|ed| |197|9|)| led| the| team| to| four| Super| Bowl| titles| (|X|VI|,| XIX|,| XX|III|,| XX|IV|).| <|br|>|•| Hall|‑|of|‑|F|ame| receivers| **|Jerry| |Rice|**,| **|John| |Taylor|**,| and| **|Roger| |Craig|**| formed| a| legendary| passing| attack|.| |
# ||| **|Steve| |Young| &| Late|‑|90|s| Success| (|199|4|‑|199|9|)**| || •| **|Steve| |Young|**| replaced| Montana|,| guiding| the| |49|ers| to| a| **|Super| Bowl| XXX|II|**| appearance| (|199|8|)| and| a| **|Super| Bowl| XXX|VII|**| win| (|199|9|).| |
# ||| **|Post|‑|200|0| Str|ugg|les| (|200|0|‑|201|0|)**| || •| After| the| retirement| of| key| veterans|,| the| team| endured| several| losing| seasons|,| including| a| |2|‑|14| record| in| |200|4|.| <|br|>|•| Not|able| players|:| **|Jeff| |F|ry|e|**,| **|Ter|rell| |Ow|ens|**,| **|Frank| |G|iff|ord|**| (|coach|).| |
# ||| **|The| Kyle| Shan|ahan| Revival| (|201|7|‑|present|)**| || •| **|Kyle| Shan|ahan|**| hired| as| head| coach|,| with| **|John| |Har|b|augh|**| as| GM|.| <|br|>|•| Developed| a| dynamic| offense| built| around| mobile| quarterback| **|Jimmy| |G|arf|ett|**| (|draft|ed| |201|4|).| <|br|>|•| Re|ached| **|Super| Bowl| LIV|**| (|202|0|)| –| lost| to| the| Kansas| City| Chiefs|.| <|br|>|•| Cons|ist|ently| among| NFC| playoff| teams| (|202|1|‑|202|3|).| |
#
# |---
#
# |##| Championships| &| Major| Ach|ievements|
#
# ||| Title| || Year|(s|)| || Opp|onent| (|Super| Bowl|)| |
# |||-------|||---------|||----------------|-------||
# ||| **|Super| Bowl| Wins|**| || **|X|VI| (|199|2|)**|,| **|X|IX| (|199|5|)**|,| **|XX|III| (|198|9|)**|,| **|XX|IV| (|199|0|)**| || |49|ers| defeated| the| **|Washington| Redskins|**,| **|Miami| Dolphins|**,| **|C|incinnati| Bengals|**,| and| **|Denver| Broncos|**,| respectively|.| |
# ||| **|NFL| Championship| (|pre|‑|Super| Bowl|)**| || **|195|2|**| || Def|e|ated| the| **|C|leveland| Browns|**|.| |
# ||| **|Conference| Championships|**| || |7| (|197|0|,| |198|1|,| |198|4|,| |198|8|,| |198|9|,| |199|4|,| |201|9|)| || NFC| titles| (|the| |197|0| title| was| in| the| pre|‑|mer|ger| era|).| |
# ||| **|Division| Titles|**| || |20|+| (|most| recent| |202|3|)| || NFC| West| dominance| in| the| |198|0|s|,| early| |199|0|s|,| and| again| in| the| |202|0|s|.| |
#
# |---
#
# |##| Hall|‑|of|‑|F|ame| Players| (|selected|)
#
# ||| Position| || Player| || Years| with| |49|ers| || Not|able| Honors| |
# |||----------|||--------|||----------------|--|||----------------||
# ||| QB| || **|Joe| |Mont|ana|**| || |197|9|‑|199|2| || |4|×| Super| Bowl| MVP|,| |2|×| NFL| MVP| |
# ||| QB| || **|Steve| |Young|**| || |198|7|‑|199|9| || |199|2| NFL| MVP|,| Hall| of| Fame| (|200|5|)| |
# ||| RB| || **|Roger| |Craig|**| || |198|3|‑|199|0| || |2|×| NFL| rushing| leader|,| |3|×| Pro| Bowl| |
# ||| WR| || **|Jerry| |Rice|**| || |198|5|‑|200|0| || |13|×| Pro| Bowl|,| |3|×| Super| Bowl| MVP|,| all|‑|time| receiving| yards|/|TD|s| (|now| surpassed|)| |
# ||| WR| || **|John| |Taylor|**| || |198|8|‑|199|9| || |5|×| Pro| Bowl|,| |2|×| Super| Bowl| champion| |
# ||| LB| || **|Patrick| |Phill|ips|**| || |199|0|‑|199|9| || |4|×| Super| Bowl| champion|,| |8|×| Pro| Bowl| |
# ||| DE| || **|Charles| | Haley|**| || |199|2|‑|199|9| || |5|×| Super| Bowl| champion| (|2| with| |49|ers|,| |3| with| Broncos|)| |
# ||| S| || **| Ronnie| |L|ott|**| || |198|1|‑|199|0| || |8|×| Pro| Bowl|,| |4|×| Super| Bowl| champion| |
# ||| DT| || **|Bry|ant| |Young|**| || |199|4|‑|200|5| || |5|×| Pro| Bowl|,| |3|×| Super| Bowl| champion| |
#
# |---
#
# |##| Recent| Seasons| (|202|1|‑|202|3|)
#
# ||| Season| || Record| (|W|‑|L|)| || Play|off| Result| || Key| Story|lines| |
# |||--------|||--------------|||----------------|||----------------||
# ||| **|202|1|**| || |10|‑|7| || Lost| Wild|‑|Card| to| **|Dallas| Cowboys|**| (|19|‑|12|)| || Jimmy| |G|arf|ett|’s| |4|,|000|‑|yard| passing| season|;| emergence| of| tight| end| **|George| |K|ittle|**| as| a| top| play|maker|.| |
# ||| **|202|2|**| || |13|‑|4| || Lost| Div|isional| Round| to| **|Philadelphia| Eagles|**| (|31|‑|7|)| || Defense| improved| under| coordinator| **|De|M|eco| Ry|ans|**|;| rookie| WR| **|J|alen| |Camp|bell|**| made| immediate| impact|.| |
# ||| **|202|3|**| || |12|‑|5| || Lost| Wild|‑|Card| to| **|Seattle| Seahawks|**| (|27|‑|24|)| || Gar|f|ett| set| franchise| record| for| most| passing| yards| in| a| season|;| **|Nick| |B|osa|**| (|ac|quired| |202|3|)| bol|stered| pass| rush|.| |
#
# |---
#
# |##| Current| R|oster| Highlights| (|202|4|)
#
# ||| Position| || Player| || Not|able| Traits| |
# |||----------|||--------|||----------------||
# ||| QB| || **|Jimmy| |G|arf|ett|**| || Dual|‑|th|reat|,| |4|,|800|+| passing| yards| in| |202|3|,| |30|+| TD|s| |
# ||| RB| || **|Christian| |Mc|C|aff|rey|**| || Vers|atile| all|‑|purpose| back|,| |1|,|300|+| scr|imm|age| yards| in| |202|3| |
# ||| WR| || **|De|ebo| |Samuel|**| || Hybrid| receiver|/r|unning| back|,| big|‑|play| ability| |
# ||| TE| || **|George| |K|ittle|**| || Elite| blocker|,| |1|,|000|+| receiving| yards| in| multiple| seasons| |
# ||| LB| || **|Fred| | Warner|**| || Defensive| leader|,| high| tackle| count| |
# ||| DE| || **|Nick| |B|osa|**| || Pro| Bowl| pass|‑|r|usher|,| |12|‑|13| sacks| per| season| |
# ||| CB| || **|J|imm|ie| |Ward|**| || Lock|down| corner|,| top|‑|10| in| passes| defended| |
#
# |---
#
# |##| Coaching| Philosophy|
#
# |-| **|Off|ense|:**| Kyle| |Sh|an|ahan|’s| system| emphasizes| **|pre|‑|snap| motion|**,| **|play|‑|action|**,| and| **|zone|‑|running| concepts|**| that| create| mism|atches|.| The| scheme| thrives| on| a| **|mobile| quarterback|**| who| can| extend| plays|.
# |-| **|Defense|:**| Under| defensive| coordinator| **|De|M|eco| |Ry|ans|**| (|until| |202|4|),| the| |49|ers| employ| a| **|multiple|‑|front|**| approach|,| blending| a| strong| **|pass| rush|**| with| **|coverage| versatility|**|.| The| goal| is| to| generate| pressure| without| over|‑|re|lying| on| blitz|es|,| allowing| lineback|ers| and| defensive| backs| to| make| plays|.
#
# |---
#
# |##| Fan| Culture| &| Trad|itions|
#
# |-| **|“|The| Faith|ful|”|**| –| The| nickname| for| the| |49|ers| fan| base|,| known| for| its| loyalty| despite| periods| of| struggle|.
# |-| **|Gold| Rush|**| –| The| team|’s| mascot|,| a| gold| miner|,| reflects| the| California| Gold| Rush| heritage|.
# |-| **|“|The| |49|ers| March|”|**| –| A| fight| song| played| after| touchdowns| at| Levi|’s| Stadium|.
# |-| **|“|The| Red| and| Gold|”|**| –| Fans| often| wear| scar|let| shirts|,| gold| hats|,| and| wave| **|“|SF|”|**| flags|.
# |-| **|R|ival|ries|:**| Primary| rivalry| with| the| **|Seattle| Seahawks|**| (|N|FC| West|),| also| historic| battles| with| the| **|Los| |Ang|eles| Rams|**| and| **|Dallas| Cowboys|**| (|especially| during| the| |199|0|s| Super| Bowl| era|).
#
# |---
#
# |##| Quick| Facts|
#
# |-| **|First| Draft| Pick|:**| **|Harry| B|abc|ock|**| (|193|6|)| –| but| the| modern| franchise| began| in| |194|6|.
# |-| **|Most| Valuable| Player| (|M|VP|)| Winners|:**| Joe| |Mont|ana| (|198|9|,| |199|0|),| Steve| |Young| (|199|2|),| Jimmy| |G|arf|ett| (|202|2| –| AP| MVP|).
# |-| **|All|‑|Time| Leading| Pass|er|:**| **|Jimmy| |G|arf|ett|**| (|as| of| |202|3|)| –| surpassed| Joe| |Mont|ana|’s| franchise| record|.
# |-| **|All|‑|Time| Leading| R|usher|:**| **|Frank| |G|iff|ord|**| (|197|2|)| –| later| overt|aken| by| **|Roger| |Craig|**| and| **|G|arrison| |Hear|st|**|.
# |-| **|All|‑|Time| Leading| Receiver|:**| **|Jerry| |Rice|**| (|13|,|528| yards|,| |197| TD|s|)| –| held| the| NFL| record| for| >|20| years|.
#
# |---
#
# |###| Bottom| Line|
#
# |The| **|San| |Franc|isco| |49|ers|**| are| one| of| the| NFL|’s| most| stor|ied| franchises|,| known| for| pioneering| offensive| innovation|,| a| parade| of| Hall|‑|of|‑|F|ame| talent|,| and| a| passionate| fan| base|.| After| a| dominant| stretch| in| the| |198|0|s|‑|early| |199|0|s| that| produced| four| Super| Bowl| titles|,| the| team| experienced| ups| and| downs| before| re|‑|em|erging| as| a| perennial| contender| under| Kyle| |Sh|an|ahan| and| Jimmy| |G|arf|ett|.| With| a| solid| core| of| play|makers| on| both| sides| of| the| ball| and| a| modern| stadium| in| Levi|’s|,| the| |49|ers| continue| to| chase| the| elusive| fifth| Super| Bowl| championship|.|||

# %% [markdown]
# ### Streaming with LangGraph API
#
# **⚠️ Notice**
#
# Since filming these videos, we've updated Studio so that it can now be run locally and accessed through your browser. This is the preferred way to run Studio instead of using the Desktop App shown in the video. It is now called _LangSmith Studio_ instead of _LangGraph Studio_. Detailed setup instructions are available in the "Getting Setup" guide at the start of the course. You can find a description of Studio [here](https://docs.langchain.com/langsmith/studio), and specific details for local deployment [here](https://docs.langchain.com/langsmith/quick-start-studio#local-development-server).
# To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the **Studio UI** URL shown above.
#
# The LangGraph API  [supports editing graph state](https://docs.langchain.com/langsmith/add-human-in-the-loop).

# %%
from langgraph_sdk import get_client

# This is the URL of the local development server
URL = "http://127.0.0.1:2024"
client = get_client(url=URL)

# Search all hosted graphs
assistants = await client.assistants.search()

# %% [markdown]
# Let's [stream `values`](https://docs.langchain.com/oss/python/langgraph/streaming#stream-graph-state), like before.

# %%
# Create a new thread
thread = await client.threads.create()
# Input message
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="streaming", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="values"):
    print(event)
# Out:
# StreamPart(event='metadata', data={'run_id': '01a07d08-d55e-7101-8025-99689df65eed', 'attempt': 1}, id=None)
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '24e4374f-be5b-44fc-a905-a34e033c9f23'}]}, id=None)
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '24e4374f-be5b-44fc-a905-a34e033c9f23'}, {'content': 'The product of\u202f2\u202fand\u202f3\u202fis\u202f6.', 'additional_kwargs': {'reasoning_content': 'User asks: "Multiply 2 and 3". Simple. Provide answer 6.'}, 'response_metadata': {'token_usage': {'completion_tokens': 42, 'prompt_tokens': 77, 'total_tokens': 119, 'completion_time': 0.087521002, 'completion_tokens_details': {'reasoning_tokens': 19}, 'prompt_time': 0.003105988, 'prompt_tokens_details': None, 'queue_time': 0.215792339, 'total_time': 0.09062699}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_19b184c447', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, 'type': 'ai', 'name': None, 'id': 'lc_run--01a07d08-d984-73f1-88a3-9ef2e21e326e-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 77, 'output_tokens': 42, 'total_tokens': 119, 'output_token_details': {'reasoning': 19}}}]}, id=None)

# %% [markdown]
# The streamed objects have:
#
# * `event`: Type
# * `data`: State

# %%
from langchain_core.messages import convert_to_messages
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], assistant_id="streaming", input={"messages": [input_message]}, stream_mode="values"):
    messages = event.data.get('messages',None)
    if messages:
        print(convert_to_messages(messages)[-1])
    print('='*25)
# Out:
# =========================
# content='Multiply 2 and 3' additional_kwargs={} response_metadata={} id='da517d16-6ea4-473a-acfe-1df4e5f5acbd'
# =========================
# content='2\u202f×\u202f3\u202f=\u202f6.' additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 77, 'output_tokens': 49, 'total_tokens': 126, 'output_token_details': {'reasoning': 30}}, 'reasoning_content': 'The user asks: "Multiply 2 and 3". This is a simple arithmetic request. The answer is 6. No policy issues.'} response_metadata={'token_usage': {'completion_tokens': 49, 'prompt_tokens': 77, 'total_tokens': 126, 'completion_time': 0.104424753, 'completion_tokens_details': {'reasoning_tokens': 30}, 'prompt_time': 0.003074548, 'prompt_tokens_details': None, 'queue_time': 0.27398071, 'total_time': 0.107499301}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_24c9ecc6e8', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--01a07d09-1d79-7062-b2e6-0b54242dc3a5-0' tool_calls=[] invalid_tool_calls=[]
# =========================

# %% [markdown]
# There are some new streaming mode that are only supported via the API.
#
# For example, we can  [use `messages` mode](https://docs.langchain.com/oss/python/langgraph/streaming#supported-stream-modes) to better handle the above case!
#
# This mode currently assumes that you have a `messages` key in your graph, which is a list of messages.
#
# All events emitted using `messages` mode have two attributes:
#
# * `event`: This is the name of the event
# * `data`: This is data associated with the event

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="streaming", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="messages"):
    print(event.event)
# Out:
# metadata
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial

# %% [markdown]
# We can see a few events:
#
# * `metadata`: metadata about the run
# * `messages/complete`: fully formed message
# * `messages/partial`: chat model tokens
#
# <!--You can dig further into the types [~here~](https://langchain-ai.github.io/langgraph/cloud/concepts/api/#modemessages) [here](https://docs.langchain.com/oss/python/langgraph/concepts/langgraph_server). -->
#
# Now, let's show how to stream these messages.
#
# We'll define a helper function for better formatting of the tool calls in messages.

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")

def format_tool_calls(tool_calls):
    """
    Format a list of tool calls into a readable string.

    Args:
        tool_calls (list): A list of dictionaries, each representing a tool call.
            Each dictionary should have 'id', 'name', and 'args' keys.

    Returns:
        str: A formatted string of tool calls, or "No tool calls" if the list is empty.

    """

    if tool_calls:
        formatted_calls = []
        for call in tool_calls:
            formatted_calls.append(
                f"Tool Call ID: {call['id']}, Function: {call['name']}, Arguments: {call['args']}"
            )
        return "\n".join(formatted_calls)
    return "No tool calls"

async for event in client.runs.stream(
    thread["thread_id"],
    assistant_id="streaming",
    input={"messages": [input_message]},
    stream_mode="messages",):
    
    # Handle metadata events
    if event.event == "metadata":
        print(f"Metadata: Run ID - {event.data['run_id']}")
        print("-" * 50)
    
    # Handle partial message events
    elif event.event == "messages/partial":
        for data_item in event.data:
            # Process user messages
            if "role" in data_item and data_item["role"] == "user":
                print(f"Human: {data_item['content']}")
            else:
                # Extract relevant data from the event
                tool_calls = data_item.get("tool_calls", [])
                invalid_tool_calls = data_item.get("invalid_tool_calls", [])
                content = data_item.get("content", "")
                response_metadata = data_item.get("response_metadata", {})

                if content:
                    print(f"AI: {content}")

                if tool_calls:
                    print("Tool Calls:")
                    print(format_tool_calls(tool_calls))

                if invalid_tool_calls:
                    print("Invalid Tool Calls:")
                    print(format_tool_calls(invalid_tool_calls))

                if response_metadata and response_metadata.get("finish_reason"):
                    print(f"Response Metadata: Finish Reason - {response_metadata['finish_reason']}")                    
        print("-" * 50)
# Out:
# Metadata: Run ID - 01a07d09-9347-7531-9119-55897c0d89cd
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# AI: 2
# --------------------------------------------------
# AI: 2
# --------------------------------------------------
# AI: 2 ×
# --------------------------------------------------
# AI: 2 ×
# --------------------------------------------------
# AI: 2 × 3
# --------------------------------------------------
# AI: 2 × 3
# --------------------------------------------------
# AI: 2 × 3 =
# --------------------------------------------------
# AI: 2 × 3 =
# --------------------------------------------------
# AI: 2 × 3 = 6
# --------------------------------------------------
# AI: 2 × 3 = 6.
# --------------------------------------------------
# AI: 2 × 3 = 6.
# Response Metadata: Finish Reason - stop
# --------------------------------------------------
# AI: 2 × 3 = 6.
# Response Metadata: Finish Reason - stop
# --------------------------------------------------
